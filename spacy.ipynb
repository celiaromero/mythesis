# %% [markdown]
# # Topic Modelling

# %%
import pandas as pd

# %%
# Read CSVs, only columns of interest
## Cordis
cordish2020 = pd.read_csv("data/cordis/cordis-h2020projects.csv",sep=";",usecols=['id','objective'])
cordisfp6 = pd.read_csv("data/cordis/cordis-fp6projects.csv",sep=";",usecols=['id','objective'])
cordisfp7 = pd.read_csv("data/cordis/cordis-fp7projects.csv",sep=";",usecols=['id','objective'])
cordis = cordish2020.append(cordisfp7)
cordis = cordis.append(cordisfp6)
## NSF
nsf = pd.read_csv('data/nsf/nsf.csv',usecols=['AwardID','AbstractNarration'])

# Rename columns to match headers later
cordis = cordis.rename(columns={'objective':'abstract'})
nsf = nsf.rename(columns={'AwardID':'id','AbstractNarration':'abstract'})

# Add source of documents to identifier
cordis['id'] = 'EU_' + cordis['id'].astype(str)
nsf['id'] = 'NSF_' + nsf['id'].astype(str)

# Join dataframes into 1
corpusdata = cordis.append(nsf)
corpusdata
# Out:
#                    id                                           abstract
# 0           EU_672890  'The project targets all luxury fashion firms ...
# 1           EU_633814  EU's agricultural and forestry land provides a...
# 2           EU_785419  According to the Global Market Forecast, there...
# 3           EU_721362  In the aerospace industry very high quality st...
# 4           EU_861924  Large areas of agricultural land in W. and N. ...
# ...               ...                                                ...
# 688501  NSF_1614484.0  A few micro-seconds after the Big Bang the uni...
# 688502  NSF_1624547.0  Calcium sulfate in crystalline form (anhydrite...
# 688503  NSF_1604697.0  The Rocky Mountain-Great Plains Graduate Resea...
# 688504  NSF_1653917.0  Investments made across national boundaries cr...
# 688505  NSF_1622136.0  This Small Business Innovation Research Phase ...
#
# [756527 rows x 2 columns]

# %%
corpusdata.dtypes
# Out:
# id          object
# abstract    object
# lemmas      object
# dtype: object

# %% [markdown]
# ## Spacy

# %%
import spacy
from termcolor import colored

# %% [markdown]
# ### 1. Introduction & basic usage

# %%
nlp = spacy.load('en_core_web_md')
doc = nlp(corpusdata['abstract'].iloc[0])

# %%
print(colored('============= Original Text =============', 'blue'))
print(doc)
print(colored('\n============= Lemmatized Text =============', 'red'))
print(' '.join([tk.lemma_ for tk in doc]))
print(colored('\n============= Entities Found =============', 'green'))
print('\n'.join([ent.text for ent in doc.ents]))
# Out:
# ============= Original Text =============
# 'The project targets all luxury fashion firms that specifically manufacture classic menswear clothing (i.e. shirts, jackets, pants, coats...) and propose its personalisation. On one hand, personalisation is a great opportunity to provide the final clients with the cloths they desire, but on the other luxury fashion houses are facing the increasing need of having some automated solutions that will help them in creating 'customized product' in a faster lead time. In fact all fashion houses manufacturing menswear are focused on providing Made to Measure products to their customers, because it increases their revenues, but at the same time this also increases their costs.  An integrated and automated management of the whole value chain will decrease the lead time, increase customization application and decrease costs.
# Crea Solution Srl proposes the TailorFit solution that will dramatically accelerate the timing of the whole process, by managing every step of the cloths manufacturing: 1) Acquisition of body measures and selection of the type of clothing, collected in a store anywhere in the world or online, 2) Outfit design: data are sent to an intelligent CAD-based system that will generate the optimal person-tailored outfit design starting from the chosen cloths model, 3) Outfit manufacturing: a software will identify the optimized fabric cut according to the tissue and its physical characteristics (i.e. the deformation of the fabric) and then will cut it rapidly allowing time and fabric savings.
# TailorFit solution is innovative compared to existing ones as those do not provide the management of the entire process, but rather they separate it into parts, do not allow customers to have an integration with the web, do not handle the perfect cut of fabrics and cutting times are operational only for striped fabrics and paintings.
# '
#
# ============= Lemmatized Text =============
# ' the project target all luxury fashion firm that specifically manufacture classic menswear clothing ( i.e. shirt , jacket , pant , coat ... ) and propose its personalisation . on one hand , personalisation be a great opportunity to provide the final client with the cloth they desire , but on the other luxury fashion house be face the increase need of have some automate solution that will help they in create ' customize product ' in a fast lead time . in fact all fashion house manufacture menswear be focus on provide make to measure product to their customer , because it increase their revenue , but at the same time this also increase their cost .   an integrated and automate management of the whole value chain will decrease the lead time , increase customization application and decrease cost .
#  Crea Solution Srl propose the TailorFit solution that will dramatically accelerate the timing of the whole process , by manage every step of the cloth manufacture : 1 ) Acquisition of body measure and selection of the type of clothing , collect in a store anywhere in the world or online , 2 ) outfit design : datum be send to an intelligent CAD - base system that will generate the optimal person - tailor outfit design start from the choose cloth model , 3 ) outfit manufacturing : a software will identify the optimize fabric cut accord to the tissue and its physical characteristic ( i.e. the deformation of the fabric ) and then will cut it rapidly allow time and fabric saving .
#  TailorFit solution be innovative compare to exist one as those do not provide the management of the entire process , but rather they separate it into part , do not allow customer to have an integration with the web , do not handle the perfect cut of fabric and cut time be operational only for striped fabric and painting .
#  '
#
# ============= Entities Found =============
# one
# Crea
# Srl
# TailorFit
# 1
# 2
# CAD
# 3
# TailorFit

# %% [markdown]
# ### 2. Architecture (vocabulary)

# %%
vocab = []
for wd in nlp.vocab:
    vocab.append([wd.text, wd.orth, wd.is_stop])

vocab = pd.DataFrame(vocab, columns=['Term', 'Hash', 'Stopword'])
vocab
# Out:
#        Term                  Hash  Stopword
# 0    nuthin  17780520906925867008     False
# 1        ü.   9616619598791593984     False
# 2       p.m   6364458155313776643     False
# 3       Kan   8969436956900823045     False
# 4       Mar  12595687976425261068     False
# ..      ...                   ...       ...
# 915   She's   7021531544473137138     False
# 916      ve  10105644630884274164     False
# 917    E.g.   4115108073383360500     False
# 918     :-|    280013313535684598     False
# 919      :*  13087474692530913272     False
#
# [920 rows x 3 columns]

# %%
stopw = vocab[vocab['Stopword']==True]
stopw
# Out:
#          Term                  Hash  Stopword
# 19         it  10239237003504588839      True
# 32         is   3411606890003347522      True
# 35      Might   9747367433533540424      True
# 42      where  16318918034475841628      True
# 50       some   7000492816108906599      True
# ..        ...                   ...       ...
# 865       Had   6865576549405853585      True
# 886    should  10292920167869855674      True
# 894       are   5012629990875267006      True
# 898  anywhere   5899329028063008718      True
# 903       and   2283656566040971221      True
#
# [133 rows x 3 columns]

# %% [markdown]
# ### 3. Word tokenization

# %%
print(colored('============= The original text information is still kept in the Doc object =============', 'blue'))
print(doc)

print(colored('\n============= Identified Tokens =============', 'red'))
for token in doc:
    print(token.text, end='\t\t')
# print('\t\t'.join([token.text for token in doc]))
# Out:
# ============= The original text information is still kept in the Doc object =============
# 'The project targets all luxury fashion firms that specifically manufacture classic menswear clothing (i.e. shirts, jackets, pants, coats...) and propose its personalisation. On one hand, personalisation is a great opportunity to provide the final clients with the cloths they desire, but on the other luxury fashion houses are facing the increasing need of having some automated solutions that will help them in creating 'customized product' in a faster lead time. In fact all fashion houses manufacturing menswear are focused on providing Made to Measure products to their customers, because it increases their revenues, but at the same time this also increases their costs.  An integrated and automated management of the whole value chain will decrease the lead time, increase customization application and decrease costs.
# Crea Solution Srl proposes the TailorFit solution that will dramatically accelerate the timing of the whole process, by managing every step of the cloths manufacturing: 1) Acquisition of body measures and selection of the type of clothing, collected in a store anywhere in the world or online, 2) Outfit design: data are sent to an intelligent CAD-based system that will generate the optimal person-tailored outfit design starting from the chosen cloths model, 3) Outfit manufacturing: a software will identify the optimized fabric cut according to the tissue and its physical characteristics (i.e. the deformation of the fabric) and then will cut it rapidly allowing time and fabric savings.
# TailorFit solution is innovative compared to existing ones as those do not provide the management of the entire process, but rather they separate it into parts, do not allow customers to have an integration with the web, do not handle the perfect cut of fabrics and cutting times are operational only for striped fabrics and paintings.
# '
#
# ============= Identified Tokens =============
# '		The		project		targets		all		luxury		fashion		firms		that		specifically		manufacture		classic		menswear		clothing		(		i.e.		shirts		,		jackets		,		pants		,		coats		...		)		and		propose		its		personalisation		.		On		one		hand		,		personalisation		is		a		great		opportunity		to		provide		the		final		clients		with		the		cloths		they		desire		,		but		on		the		other		luxury		fashion		houses		are		facing		the		increasing		need		of		having		some		automated		solutions		that		will		help		them		in		creating		'		customized		product		'		in		a		faster		lead		time		.		In		fact		all		fashion		houses		manufacturing		menswear		are		focused		on		providing		Made		to		Measure		products		to		their		customers		,		because		it		increases		their		revenues		,		but		at		the		same		time		this		also		increases		their		costs		.		 		An		integrated		and		automated		management		of		the		whole		value		chain		will		decrease		the		lead		time		,		increase		customization		application		and		decrease		costs		.
# 		Crea		Solution		Srl		proposes		the		TailorFit		solution		that		will		dramatically		accelerate		the		timing		of		the		whole		process		,		by		managing		every		step		of		the		cloths		manufacturing		:		1		)		Acquisition		of		body		measures		and		selection		of		the		type		of		clothing		,		collected		in		a		store		anywhere		in		the		world		or		online		,		2		)		Outfit		design		:		data		are		sent		to		an		intelligent		CAD		-		based		system		that		will		generate		the		optimal		person		-		tailored		outfit		design		starting		from		the		chosen		cloths		model		,		3		)		Outfit		manufacturing		:		a		software		will		identify		the		optimized		fabric		cut		according		to		the		tissue		and		its		physical		characteristics		(		i.e.		the		deformation		of		the		fabric		)		and		then		will		cut		it		rapidly		allowing		time		and		fabric		savings		.
# 		TailorFit		solution		is		innovative		compared		to		existing		ones		as		those		do		not		provide		the		management		of		the		entire		process		,		but		rather		they		separate		it		into		parts		,		do		not		allow		customers		to		have		an		integration		with		the		web		,		do		not		handle		the		perfect		cut		of		fabrics		and		cutting		times		are		operational		only		for		striped		fabrics		and		paintings		.
# 		'

# %% [markdown]
# ### 4. POS tagging

# %%
df = pd.DataFrame([[token.text, token.pos_, token.tag_] for token in doc],
                  columns = ['Token', 'POS', 'TAG'])
df
# Out:
#          Token    POS  TAG
# 0            '  PUNCT   ``
# 1          The    DET   DT
# 2      project   NOUN   NN
# 3      targets   VERB  VBZ
# 4          all    DET   DT
# ..         ...    ...  ...
# 327        and  CCONJ   CC
# 328  paintings   NOUN  NNS
# 329          .  PUNCT    .
# 330         \n  SPACE  _SP
# 331          '  PUNCT   ''
#
# [332 rows x 3 columns]

# %% [markdown]
# ### 5. Named entity recognition

# %%
df_ents = pd.DataFrame([[ent.text, ent.label_, spacy.explain(ent.label_)] for ent in doc.ents], columns=['Entity', 'Type', 'Description'])
df_ents
# Out:
#       Entity      Type                                   Description
# 0        one  CARDINAL  Numerals that do not fall under another type
# 1       Crea    PERSON                   People, including fictional
# 2        Srl       GPE                     Countries, cities, states
# 3  TailorFit       ORG       Companies, agencies, institutions, etc.
# 4          1  CARDINAL  Numerals that do not fall under another type
# 5          2  CARDINAL  Numerals that do not fall under another type
# 6        CAD       ORG       Companies, agencies, institutions, etc.
# 7          3  CARDINAL  Numerals that do not fall under another type
# 8  TailorFit       ORG       Companies, agencies, institutions, etc.

# %%
from spacy import displacy

displacy.render(doc, style="ent", jupyter=True, options={'distance': 90})

entypes = set([ent.label_ for ent in doc.ents])
df_ent = pd.DataFrame([[enttyp, spacy.explain(enttyp)] for enttyp in entypes], columns=['Entity type', 'Description'])
df_ent
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">'The project targets all luxury fashion firms that specifically manufacture classic menswear clothing (i.e. shirts, jackets, pants, coats...) and propose its personalisation. On
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  hand, personalisation is a great opportunity to provide the final clients with the cloths they desire, but on the other luxury fashion houses are facing the increasing need of having some automated solutions that will help them in creating 'customized product' in a faster lead time. In fact all fashion houses manufacturing menswear are focused on providing Made to Measure products to their customers, because it increases their revenues, but at the same time this also increases their costs.  An integrated and automated management of the whole value chain will decrease the lead time, increase customization application and decrease costs.</br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Crea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Solution
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Srl
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  proposes the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TailorFit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  solution that will dramatically accelerate the timing of the whole process, by managing every step of the cloths manufacturing:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ) Acquisition of body measures and selection of the type of clothing, collected in a store anywhere in the world or online,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ) Outfit design: data are sent to an intelligent
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CAD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# -based system that will generate the optimal person-tailored outfit design starting from the chosen cloths model,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ) Outfit manufacturing: a software will identify the optimized fabric cut according to the tissue and its physical characteristics (i.e. the deformation of the fabric) and then will cut it rapidly allowing time and fabric savings. </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TailorFit
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  solution is innovative compared to existing ones as those do not provide the management of the entire process, but rather they separate it into parts, do not allow customers to have an integration with the web, do not handle the perfect cut of fabrics and cutting times are operational only for striped fabrics and paintings.</br>'</div></span>
#   Entity type                                   Description
# 0    CARDINAL  Numerals that do not fall under another type
# 1         ORG       Companies, agencies, institutions, etc.
# 2      PERSON                   People, including fictional
# 3         GPE                     Countries, cities, states

# %% [markdown]
# ### 6. Lemmatization

# %%
print(colored('============= Original text =============', 'blue'))
print(doc.text)
print(colored('\n============= Lemmas =============', 'red'))
print(' '.join([token.lemma_ for token in doc]))
# Out:
# ============= Original text =============
# 'The project targets all luxury fashion firms that specifically manufacture classic menswear clothing (i.e. shirts, jackets, pants, coats...) and propose its personalisation. On one hand, personalisation is a great opportunity to provide the final clients with the cloths they desire, but on the other luxury fashion houses are facing the increasing need of having some automated solutions that will help them in creating 'customized product' in a faster lead time. In fact all fashion houses manufacturing menswear are focused on providing Made to Measure products to their customers, because it increases their revenues, but at the same time this also increases their costs.  An integrated and automated management of the whole value chain will decrease the lead time, increase customization application and decrease costs.
# Crea Solution Srl proposes the TailorFit solution that will dramatically accelerate the timing of the whole process, by managing every step of the cloths manufacturing: 1) Acquisition of body measures and selection of the type of clothing, collected in a store anywhere in the world or online, 2) Outfit design: data are sent to an intelligent CAD-based system that will generate the optimal person-tailored outfit design starting from the chosen cloths model, 3) Outfit manufacturing: a software will identify the optimized fabric cut according to the tissue and its physical characteristics (i.e. the deformation of the fabric) and then will cut it rapidly allowing time and fabric savings.
# TailorFit solution is innovative compared to existing ones as those do not provide the management of the entire process, but rather they separate it into parts, do not allow customers to have an integration with the web, do not handle the perfect cut of fabrics and cutting times are operational only for striped fabrics and paintings.
# '
#
# ============= Lemmas =============
# ' the project target all luxury fashion firm that specifically manufacture classic menswear clothing ( i.e. shirt , jacket , pant , coat ... ) and propose its personalisation . on one hand , personalisation be a great opportunity to provide the final client with the cloth they desire , but on the other luxury fashion house be face the increase need of have some automate solution that will help they in create ' customize product ' in a fast lead time . in fact all fashion house manufacture menswear be focus on provide make to measure product to their customer , because it increase their revenue , but at the same time this also increase their cost .   an integrated and automate management of the whole value chain will decrease the lead time , increase customization application and decrease cost .
#  Crea Solution Srl propose the TailorFit solution that will dramatically accelerate the timing of the whole process , by manage every step of the cloth manufacture : 1 ) Acquisition of body measure and selection of the type of clothing , collect in a store anywhere in the world or online , 2 ) outfit design : datum be send to an intelligent CAD - base system that will generate the optimal person - tailor outfit design start from the choose cloth model , 3 ) outfit manufacturing : a software will identify the optimize fabric cut accord to the tissue and its physical characteristic ( i.e. the deformation of the fabric ) and then will cut it rapidly allow time and fabric saving .
#  TailorFit solution be innovative compare to exist one as those do not provide the management of the entire process , but rather they separate it into part , do not allow customer to have an integration with the web , do not handle the perfect cut of fabric and cut time be operational only for striped fabric and painting .
#  '

# %% [markdown]
# ### Pipeline

# %%
nlp.disable_pipe('parser')
nlp.disable_pipe('ner')

valid_POS = set(['VERB', 'NOUN', 'ADJ', 'PROPN'])
specific_stw = set(['relevant', 'simple', 'base'])

def text_preprocessing(rawtext):
    lemmatized = ' '.join([token.lemma_ for token in doc 
                           if token.is_alpha
                           and token.pos_ in valid_POS
                           and not token.is_stop
                           and token.lemma_ not in specific_stw])
    return lemmatized

print(colored('============= Original text =============', 'blue'))
print(doc)
print(colored('\n============= Lemmatized text =============', 'red'))
print(text_preprocessing(doc))
# Out:
# ============= Original text =============
# 'The project targets all luxury fashion firms that specifically manufacture classic menswear clothing (i.e. shirts, jackets, pants, coats...) and propose its personalisation. On one hand, personalisation is a great opportunity to provide the final clients with the cloths they desire, but on the other luxury fashion houses are facing the increasing need of having some automated solutions that will help them in creating 'customized product' in a faster lead time. In fact all fashion houses manufacturing menswear are focused on providing Made to Measure products to their customers, because it increases their revenues, but at the same time this also increases their costs.  An integrated and automated management of the whole value chain will decrease the lead time, increase customization application and decrease costs.
# Crea Solution Srl proposes the TailorFit solution that will dramatically accelerate the timing of the whole process, by managing every step of the cloths manufacturing: 1) Acquisition of body measures and selection of the type of clothing, collected in a store anywhere in the world or online, 2) Outfit design: data are sent to an intelligent CAD-based system that will generate the optimal person-tailored outfit design starting from the chosen cloths model, 3) Outfit manufacturing: a software will identify the optimized fabric cut according to the tissue and its physical characteristics (i.e. the deformation of the fabric) and then will cut it rapidly allowing time and fabric savings.
# TailorFit solution is innovative compared to existing ones as those do not provide the management of the entire process, but rather they separate it into parts, do not allow customers to have an integration with the web, do not handle the perfect cut of fabrics and cutting times are operational only for striped fabrics and paintings.
# '
#
# ============= Lemmatized text =============
# project target luxury fashion firm manufacture classic menswear clothing shirt jacket pant coat propose personalisation hand personalisation great opportunity provide final client cloth desire luxury fashion house face increase need have automate solution help create customize product fast lead time fact fashion house manufacture menswear focus provide measure product customer increase revenue time increase cost integrated automate management value chain decrease lead time increase customization application decrease cost Crea Solution Srl propose TailorFit solution accelerate timing process manage step cloth manufacture Acquisition body measure selection type clothing collect store world outfit design datum send intelligent CAD system generate optimal person tailor outfit design start choose cloth model outfit manufacturing software identify optimize fabric cut accord tissue physical characteristic deformation fabric cut allow time fabric saving TailorFit solution innovative compare exist one provide management entire process separate part allow customer integration web handle perfect cut fabric cut time operational striped fabric painting

# %%
corpusdata['lemmas'] = None
corpusdata = textdata[textdata['abstract'].notnull()]

for i in range(628061,len(corpusdata)):
    doc = nlp(corpusdata['abstract'].iloc[i])
    corpusdata['lemmas'].iloc[i] = text_preprocessing(doc)

corpusdata.head()
# Out:
#           id                                           abstract  \
# 0  EU_672890  'The project targets all luxury fashion firms ...
# 1  EU_633814  EU's agricultural and forestry land provides a...
# 2  EU_785419  According to the Global Market Forecast, there...
# 3  EU_721362  In the aerospace industry very high quality st...
# 4  EU_861924  Large areas of agricultural land in W. and N. ...
#
#                                               lemmas
# 0  project target luxury fashion firm manufacture...
# 1  EU agricultural forestry land provide wide ran...
# 2  accord Global Market Forecast strong need ramp...
# 3  aerospace industry high quality standard meet ...
# 4  large area agricultural land Africa degrade wa...

# %%
corpusdata.to_csv('data/corpus_lemmatized.csv')
